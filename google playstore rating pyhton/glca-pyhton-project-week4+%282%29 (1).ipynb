# %%
# Assignment :- EDA & Data Preprocessing on Google App Store Rating Dataset

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Ramandeep\OneDrive\drive178\OneDrive\Desktop\Apps_data+(1).csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# 3. Check summary statistics of the dataset. List out the columns that need to be worked upon for model building.

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
 # we need to convert our Category , Genres , type and content rating into the int data type through our encoding techniques and 
# I think current version column is not much needed for the model building as it not properly sepecify the version in many rows.

# %%
# 4. Check if there are any duplicate records in the dataset? if any drop them.

# %%
# Check for duplicate records
duplicate_rows = df[df.duplicated()]

# %%
duplicate_rows
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
# as we see we have 483 rows are there which is duplicate so now we drop those duplicate rows

# %%
df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 10358

# %%
# now we see after droping the 483 duplicate rows we have left only 10358 rows out of 10840.

# %%
# 5. Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them.

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df = df[~(df['Category'] == '1.9')]

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# now we see after droping the row which conatins 1.9 as a category we have left only 10357 rows into our main dataset.

# %%
# 6. Check if there are missing values present in the column Rating, If any? drop them and and create a new
# column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)

# %%
df['Rating'].isnull().sum()
# Out:
# 1465

# %%
df.dropna(subset = ['Rating'] , inplace = True)
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\2624225347.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset = ['Rating'] , inplace = True)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# see after droping the rows which has no Rating values using the dropna function we have only left with the 8892 rows into our dataset

# %%
df['Rating_category'] = np.where(df['Rating'] > 3.5, 'High', 'Low')
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\4258716934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating_category'] = np.where(df['Rating'] > 3.5, 'High', 'Low')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# see by using the numpy library we can convert our rating into the high or low in this where we have rating greater than 3.5 we have high and else
# we have low as our category

# %%
# 7. Check the distribution of the newly created column 'Rating_category' and comment on the distribution.

# %%
df['Rating_category'].value_counts()
# Out:
# Rating_category
# High    8012
# Low      880
# Name: count, dtype: int64

# %%
# As we see in our rating category the value of high rating is pretty much high as compared to the low rating which means our distribution is skew 
# towards high rating category and our Rating for most of the apps are greater than 3.5.

# %%
# 8. Convert the column "Reviews'' to numeric data type and check the presence of outliers in the column and
# handle the outliers using a transformation approach.(Hint: Use log transformation)

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'])
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\4153836384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Reviews'] = pd.to_numeric(df['Reviews'])

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size                object
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
import seaborn as sns

# %%
sns.boxplot(df['Reviews'])
# Out:
# <Axes: ylabel='Reviews'>

# %%
# as we see there are more number of outliers into our data set so we need to remove all those outlier using the log transformation technique

# %%
h = np.log2(df['Reviews'])

# %%
sns.boxplot(h)
# Out:
# <Axes: ylabel='Reviews'>

# %%
# as we see after applying our logn transformation technique we succesfuly remove all outliers from our datset.

# %%
# 9. The column 'Size' contains alphanumeric values, treat the non numeric data and convert the column into
# suitable data type. (hint: Replace M with 1 million and K with 1 thousand, and drop the entries where
# size='Varies with device')

# %%
 df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Size'] = pd.to_numeric(df['Size'].str.replace('M', 'e6').str.replace('K', 'e3'), errors='coerce')
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\585469652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size'] = pd.to_numeric(df['Size'].str.replace('M', 'e6').str.replace('K', 'e3'), errors='coerce')

# %%
df = df.dropna(subset=['Size'])

# %%
df
# Out:
#                                                      App            Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN
# 1                                    Coloring book moana      ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...      ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint      ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book      ART_AND_DESIGN
# ...                                                  ...                 ...
# 10830                                  News Minecraft.fr  NEWS_AND_MAGAZINES
# 10834                                      FR Calculator              FAMILY
# 10836                                   Sya9a Maroc - FR              FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings              FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology           LIFESTYLE
#
# ...

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size               float64
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
# here i mentioned how i do this things into our main dataset of size column.
# first: - we replace our m with e6 and k aith e3
# second :- we skip the rows where we a data like "depend upon version" with the help of error = "corec" when we do this the rows which contains this above string will convert into nan.
# third:-we convert our e3 and e6 values with pd. to_numeric.
# foruth:-then we have size column which contains only numeric and nan values.
# fifth:- we drop the nan values from our size column and its done.

# %%
# 10. Check the column 'Installs', treat the unwanted characters and convert the column into a suitable data type.

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1210
# 100,000+           967
# 10,000+            894
# 10,000,000+        754
# 1,000+             638
# 5,000,000+         489
# 500,000+           463
# 50,000+            410
# 5,000+             372
# 100+               285
# 100,000,000+       192
# 500+               189
# 50,000,000+        144
# 10+                 65
# 50+                 51
# 500,000,000+        24
# 5+                   9
# 1,000,000,000+       8
# 1+                   3
# Name: count, dtype: int64

# %%
df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '')
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\2045450040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Installs'] = df['Installs'].str.replace(',', '').str.replace('+', '')

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1210
# 100000         967
# 10000          894
# 10000000       754
# 1000           638
# 5000000        489
# 500000         463
# 50000          410
# 5000           372
# 100            285
# 100000000      192
# 500            189
# 50000000       144
# 10              65
# 50              51
# 500000000       24
# 5                9
# 1000000000       8
# 1                3
# Name: count, dtype: int64

# %%
df
# Out:
#                                                      App            Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN
# 1                                    Coloring book moana      ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...      ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint      ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book      ART_AND_DESIGN
# ...                                                  ...                 ...
# 10830                                  News Minecraft.fr  NEWS_AND_MAGAZINES
# 10834                                      FR Calculator              FAMILY
# 10836                                   Sya9a Maroc - FR              FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings              FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology           LIFESTYLE
#
# ...

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size               float64
# Installs            object
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
df['Installs'] = pd.to_numeric(df['Installs'])
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\905531866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Installs'] = pd.to_numeric(df['Installs'])

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size               float64
# Installs             int64
# Type                object
# Price               object
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
# 11. Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type.

# %%
df
# Out:
#                                                      App            Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN
# 1                                    Coloring book moana      ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...      ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint      ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book      ART_AND_DESIGN
# ...                                                  ...                 ...
# 10830                                  News Minecraft.fr  NEWS_AND_MAGAZINES
# 10834                                      FR Calculator              FAMILY
# 10836                                   Sya9a Maroc - FR              FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings              FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology           LIFESTYLE
#
# ...

# %%
df['Price'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10830    0
# 10834    0
# 10836    0
# 10837    0
# 10840    0
# Name: Price, Length: 7167, dtype: object>

# %%
df['Price'] = df['Price'].str.replace('$','')
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\1580091000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].str.replace('$','')

# %%
df['Price'] = pd.to_numeric(df['Price'])
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\3793862318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = pd.to_numeric(df['Price'])

# %%
df.dtypes
# Out:
# App                 object
# Category            object
# Rating             float64
# Reviews              int64
# Size               float64
# Installs             int64
# Type                object
# Price              float64
# Content Rating      object
# Genres              object
# Last Updated        object
# Current Ver         object
# Android Ver         object
# Rating_category     object
# dtype: object

# %%
# 12. Drop the columns which you think redundant for the analysis.(suggestion: drop column 'rating', since we
# created a new feature from it (i.e. rating_category) and the columns 'App', 'Rating' ,'Genres','Last Updated',
# 'Current Ver','Android Ver' columns since which are redundant for our analysis)

# %%
columns_to_drop = ['Rating', 'App', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
df.drop(columns=columns_to_drop, inplace=True)
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\1815351204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True)

# %%
df
# Out:
#                  Category  Reviews        Size  Installs  Type  Price  \
# 0          ART_AND_DESIGN      159  19000000.0     10000  Free    0.0
# 1          ART_AND_DESIGN      967  14000000.0    500000  Free    0.0
# 2          ART_AND_DESIGN    87510   8700000.0   5000000  Free    0.0
# 3          ART_AND_DESIGN   215644  25000000.0  50000000  Free    0.0
# 4          ART_AND_DESIGN      967   2800000.0    100000  Free    0.0
# ...                   ...      ...         ...       ...   ...    ...
# 10830  NEWS_AND_MAGAZINES      881   2300000.0    100000  Free    0.0
# 10834              FAMILY        7   2600000.0       500  Free    0.0
# 10836              FAMILY       38  53000000.0      5000  Free    0.0
# 10837              FAMILY        4   3600000.0       100  Free    0.0
# 10840           LIFESTYLE   398307  19000000.0  10000000  Free    0.0
#
#       Content Rating Rating_category
# 0           Everyone            High
# 1           Everyone            High
# ...

# %%
# 13. Encode the categorical columns.

# %%
len(df['Category'].unique())
# Out:
# 33

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['Category'] = lb.fit_transform(df['Category'])
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\3702280784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category'] = lb.fit_transform(df['Category'])

# %%
df
# Out:
#        Category  Reviews        Size  Installs  Type  Price Content Rating  \
# 0             0      159  19000000.0     10000  Free    0.0       Everyone
# 1             0      967  14000000.0    500000  Free    0.0       Everyone
# 2             0    87510   8700000.0   5000000  Free    0.0       Everyone
# 3             0   215644  25000000.0  50000000  Free    0.0           Teen
# 4             0      967   2800000.0    100000  Free    0.0       Everyone
# ...         ...      ...         ...       ...   ...    ...            ...
# 10830        21      881   2300000.0    100000  Free    0.0       Everyone
# 10834        11        7   2600000.0       500  Free    0.0       Everyone
# 10836        11       38  53000000.0      5000  Free    0.0       Everyone
# 10837        11        4   3600000.0       100  Free    0.0       Everyone
# 10840        18   398307  19000000.0  10000000  Free    0.0       Everyone
#
#       Rating_category
# 0                High
# ...

# %%
# 14. Segregate the target and independent features (Hint: Use Rating_category as the target)

# %%
cf = df

# %%
independent = cf.drop(columns=['Rating_category'])

# %%
target = df['Rating_category']

# %%
# here we create a copy of our data into the cf varibale as if we drop the Rating_category column from our copied data then it doesn't affect
# or we do not lose our Rating_cateogy column which is essential or imp into our data set for creating a machine learning model out of it

# %%
# 15. Split the dataset into train and test.

# %%
X = independent

# %%
y = target

# %%
# split the data into training and testing dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state=250)

# %%
X_train
# Out:
#        Category  Reviews        Size  Installs  Type  Price Content Rating
# 5900         15      265   4100000.0    100000  Free   0.00       Everyone
# 4616         11      146  20000000.0      5000  Paid   5.99           Teen
# 8798          3       22  34000000.0      1000  Free   0.00       Everyone
# 1141         12    11066   9100000.0    500000  Free   0.00       Everyone
# 9184         23      410   6100000.0    100000  Free   0.00       Everyone
# ...         ...      ...         ...       ...   ...    ...            ...
# 10827        11      117  13000000.0      5000  Free   0.00       Everyone
# 2811         24   142634  22000000.0  10000000  Free   0.00       Everyone
# 3724         21   293080  25000000.0  10000000  Free   0.00   Everyone 10+
# 4258         27      185   4700000.0     10000  Free   0.00           Teen
# 3052         28      361   2200000.0     50000  Free   0.00       Everyone
#
# [5375 rows x 7 columns]

# %%
y_train
# Out:
# 5900     High
# 4616     High
# 8798     High
# 1141     High
# 9184     High
#          ...
# 10827    High
# 2811     High
# 3724     High
# 4258      Low
# 3052     High
# Name: Rating_category, Length: 5375, dtype: object

# %%
X_test
# Out:
#       Category  Reviews        Size  Installs  Type  Price Content Rating
# 8376         4        3  11000000.0        10  Paid   2.49       Everyone
# 5738         3        8   3900000.0      5000  Free   0.00       Everyone
# 4774        29      514   8400000.0     50000  Free   0.00       Everyone
# 6224         3      286  18000000.0     10000  Free   0.00       Everyone
# 7839         6      125  53000000.0      5000  Free   0.00       Everyone
# ...        ...      ...         ...       ...   ...    ...            ...
# 9717        11       11  20000000.0       500  Paid   1.99   Everyone 10+
# 2060        11     4207  26000000.0    100000  Free   0.00       Everyone
# 8236        24        1   2500000.0        10  Paid   3.49       Everyone
# 4058        23    10158   3600000.0    500000  Free   0.00       Everyone
# 7921        12      196   7300000.0     10000  Free   0.00       Everyone
#
# [1792 rows x 7 columns]

# %%
y_test
# Out:
# 8376    High
# 5738    High
# 4774    High
# 6224    High
# 7839    High
#         ...
# 9717    High
# 2060    High
# 8236     Low
# 4058    High
# 7921    High
# Name: Rating_category, Length: 1792, dtype: object

# %%
# as we our data is splitted into the two parts one is our Train data by which we train our machine learning model for predictions
# and another one is our test data by which we can evaluate our machine learning model performance like shows how much errors are there into the
# predictions that our machine learning model makes upon the bases of overiew get from our train dataset.

# %%
# 16. Standardize the data, so that the values are within a particular range

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# %%
df[['Size','Installs']] = scaler.fit_transform(df[['Size','Installs']])
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_12532\871073982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Size','Installs']] = scaler.fit_transform(df[['Size','Installs']])

# %%
df
# Out:
#        Category  Reviews      Size      Installs  Type  Price Content Rating  \
# 0             0      159  0.181818  9.999000e-06  Free    0.0       Everyone
# 1             0      967  0.131313  4.999990e-04  Free    0.0       Everyone
# 2             0    87510  0.077778  4.999999e-03  Free    0.0       Everyone
# 3             0   215644  0.242424  5.000000e-02  Free    0.0           Teen
# 4             0      967  0.018182  9.999900e-05  Free    0.0       Everyone
# ...         ...      ...       ...           ...   ...    ...            ...
# 10830        21      881  0.013131  9.999900e-05  Free    0.0       Everyone
# 10834        11        7  0.016162  4.990000e-07  Free    0.0       Everyone
# 10836        11       38  0.525253  4.999000e-06  Free    0.0       Everyone
# 10837        11        4  0.026263  9.900000e-08  Free    0.0       Everyone
# 10840        18   398307  0.181818  9.999999e-03  Free    0.0       Everyone
#
#       Rating_category
# ...

# %%
# so yes as we see we scaled our values from 0 to 1 by using the minmaxscaler with the help of our sklearn library so that all the values are within
# within range and we can make analysis over dataset.

# %%
# first part of assignment is done.
# In which we use:-
# data preprocessing.
# data visulaisation.
# data scaling tecniques.
# removal of outliers by using the logn technique.

# %%
# PART 2 

# Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %%
# 1. Import required libraries and read the dataset.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv(r"C:\Users\Ramandeep\OneDrive\drive178\OneDrive\Desktop\honeyproduction.csv")

# %%
df1
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
df1.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
# 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df1.shape
# Out:
# (626, 8)

# %%
df1.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
# 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
df1
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
# Count occurrences of each year
year_counts = df1['year'].value_counts()

# Plot the pie chart
plt.figure(figsize=(10, 8))
plt.pie(year_counts, labels=year_counts.index, autopct='%1.1f%%')
plt.title('Percentage Distribution of Data by Year')
# Out:
# Text(0.5, 1.0, 'Percentage Distribution of Data by Year')

# %%
year_counts = df1['year'].value_counts()

# %%
year_counts
# Out:
# year
# 2001    44
# 2002    44
# 2003    44
# 1998    43
# 1999    43
# 2000    43
# 2004    41
# 2005    41
# 2006    41
# 2007    41
# 2008    41
# 2009    40
# 2010    40
# 2011    40
# 2012    40
# Name: count, dtype: int64

# %%
year_counts.values
# Out:
# array([44, 44, 44, 43, 43, 43, 41, 41, 41, 41, 41, 40, 40, 40, 40],
#       dtype=int64)

# %%
year_counts.index
# Out:
# Index([2001, 2002, 2003, 1998, 1999, 2000, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012],
#       dtype='int64', name='year')

# %%
# 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
df1
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
sns.displot(df1['priceperlb'], kde=True, height=6, aspect=2)

# %%
len(df1['priceperlb'].unique())
# Out:
# 210

# %%
# 1) as we see our displot is skewed towards rightward or we can say its postively skewed which means we have few high price range
# products as compared to products which we have avaliable in the bulk at the medium or lesser prices.
# 2) Here our mean is greater than median.
# 3) And if we see our priceperlb closely then we can found that our outliers is at the end or at the tail side of the data  
# this indicate certain unique products with exceptionally high prices per pound
# 4) And into this data our most common price range are 1.41 , 1.42  and 2nd highest range of price we have 0.65 and 1.40.These price ranges help us 
# to understand the market trend and most affordable price and mainly base upon this we can take our price making desecions as well.

# %%
# 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df1, x='numcol', y='prodvalue')
plt.title('Relationship between Number of honey producing colonies and Value of production')
plt.xlabel('Number of honey producing colonies')
plt.ylabel('Value of production')
plt.show()

# %%
# from the above scatter plot we can see as our number of honey producing colonies would increase the value of production would also be increasing
# and if we try to inspect closely the above scatter plot the increasing trend shows us that the number of honey producing colonies and
# value of production has strong postively corelated with each other as number of honey producing colonies increases 
# value of production would also increase.
# and from the aove scatter plot we have a outlier into the data at end.
# and the spread and concentration of datapoints shows us a strong correaltion between the varibales.

# %%
# 6 Plot and understand the relationship between categorical variable 'year' and a numerical variable
# 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df1, x='year', y='prodvalue')
plt.title('Relationship between Year and Value of production ')
plt.xlabel('Year')
plt.ylabel('Value of production')
plt.show()

# %%
# from  the above box plot which we ploted for diffrent years with respect to our value of production we examin some points;-
# As we see from the above box plot every year we have a outliers into our dataset but in year 2010, 2011, 2012 we have amore number of outliers 
# into our dataset with respect to the value of production as compare to the other years.
# And with help of above box plot we can closely examine min max q1 q2 q3 in short 5 point summary as well and we can see that in every year box
# plot data a thin line is there which shows us the q2 or medain in each year dataset.
# And after removal of outliers with the help of our logn and square techinques we can easily find our 5 point summary from the dataset.

# %%
# 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years
# using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
columns_of_interest = df1[['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year']]

# %%
columns_of_interest
# Out:
#        numcol  yieldpercol   totalprod   prodvalue  year
# 0     16000.0           71   1136000.0    818000.0  1998
# 1     55000.0           60   3300000.0   2112000.0  1998
# 2     53000.0           65   3445000.0   2033000.0  1998
# 3    450000.0           83  37350000.0  23157000.0  1998
# 4     27000.0           72   1944000.0   1361000.0  1998
# ..        ...          ...         ...         ...   ...
# 621    4000.0           41    164000.0    618000.0  2012
# 622   62000.0           41   2542000.0   6050000.0  2012
# 623    6000.0           48    288000.0    838000.0  2012
# 624   60000.0           69   4140000.0   8487000.0  2012
# 625   50000.0           51   2550000.0   4769000.0  2012
#
# [626 rows x 5 columns]

# %%
sns.pairplot(df_filtered, hue='year')
plt.show()

# %%
# NOTE :- BY CLOSELY EXAMINE THE ABOVE PAIR PLOT WE CAN EASILY EXAM(INE THE BELOW THINGS WHICH WE WERE MENTIONE>>>>>>>>>>>
# By closely examine the above pairplot which represents the relationship between 'numcol', 'yieldpercol', 'totalprod', 'prodvalue' with respect to 
# the year where we examine each column with respect to the year means here we see every year what kind of performance we have in each column.
# If we try to understand the same kind of thing we can see into our heat map it shows us the correlation mainly but in visulaization form.
# from this pairplot we can see how much values in each column has cgange in each year whaether it is our 
# Number of honey producing colonies , Honey yield per colony , total production and value of production it also shows us the coorelation between
# diffrent columns in diffrent years as how much the values has been change in each year and how strong or weekly 
# correlated the columns or variables with each others.

# %%
# 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol',
# 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
columns_of_interest = df1[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']]

# %%
columns_of_interest.corr()
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701   0.912796
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646   0.278977
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499   0.907236
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867   0.728560
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000  -0.089567
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567   1.000000

# %%
sns.heatmap(columns_of_interest.corr())
# Out:
# <Axes: >

# %%
# Positive correlated Number of honey producing colonies:-
# as we see Number of honey producing colonies has positively strong correlated with the Total production ,stocks held by producers 
# and the Value of production as the Number of honey producing colonies would increase we can see the total production,stock held by prodeucers
# and the value of production would also increase.

# Negative and weaker correlated Number of honey producing colonies:-
# as we see Honey yield per colony has a weaker postive correlation as if value of honey producing colonies would increase the increase 
# in honey yield per colony would not increase in that much amount.
# and average price per pound based on expanded sales has a neagtive correlation means as with the increase in honey producing colonies our 
# average price per pound based on expanded sales would be decrease.

# Negative and weaker correlated Honey yield per colony:-
# as we see Honey yield per colony has a weaker postive correlation as if value of Honey yield per colony would increase the increase 
# in Total production ,Value of production , stocks held by producerswould not increase in that much amount.
# and average price per pound based on expanded sales has a neagtive correlation means as with the increase in Honey yield per colony our 
# average price per pound based on expanded sales would be decrease.

# Positive correlated Total production:-
# as we see Number of honey producing colonies has positively strong correlated with the stocks held by producers
# and the Value of production as the Total production would increase we can see the total production,stocks held by producers
# and the value of production would also increase.

# Negative and weaker correlated Total production:-
# and average price per pound based on expanded sales has a neagtive correlation means as with the increase in Total production our 
# average price per pound based on expanded sales would be decrease.

# Positive correlated Number of honey producing colonies:-
# as we see stock held by prodeucers has positively strong correlated with the Value of production 
# as the stock held by prodeucers would increase we can see the Value of production would also increase.

# Negative and weaker correlated Number of honey producing colonies:-
# stock held by prodeucers has a neagtive correlation means as with the increase in stock held by prodeucers our 
# average price per pound based on expanded sales would be decrease.

# Negative and weaker correlated Number of honey producing colonies:-
# average price per pound based on expanded sales has a neagtive correlation means as with the increase 
# in average price per pound based on expanded salesour value of production would be decrease.
