# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Ramandeep\Downloads\youtube_dislike_dataset.csv")

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top
# 5 and bottom 5 records.

# %%
df.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
# 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
# As we see from the above video_id, title, channel_id, channel_title, published_at, tags, description, comments has an a object data types
# which means their data types are in string format and we can do any string operation over it.
# And view_count, Likes, dislikes, comment_count are in integer format means the are in numerical format we can do any numerical operations over it.
# we have 37422 total rows and 12 columns which gives us an idea of our data set.
# And from the data set we can clearly see that we have'nt any null values into our data sets except our comments column, our comments column have
# 158 null values.

# %%
# 3. Check for the Percentage of the missing values and drop or impute them.

# %%
df.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
(158/37422)*100 # percentage of missing values
# Out:
# 0.4222115333226444

# %%
# so from above calculated percentage we can see that its less than the threshold value so we can fillnthe null values here drop the column is not a 
# right option here

# %%
df['comments'].mode()    # as we see all the comments are unique in nature so to fill the null values here mode is not a suitable approach here.....
# Out:
# 0        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \...
# 3        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nYouTube\n\n\...
# 4        \n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n(...
#                                ...
# 37259    ||: SHE IS BORN!!! HER VOICE MUST BE LEGENDARY...
# 37260    ~                                        ..?  ...
# 37261    ~      ??( )     \n ~~\nASMR   \n   ~~   asmr ...
# 37262    ~ TIMELINE ~\n\n0:00 : Intro\n5:03 : Conseils ...
# 37263    ~!\n        ~\n  ~\n     ~~                   ...
# Name: comments, Length: 37264, dtype: object

# %%
df['comments'].fillna('Not Available', inplace=True) # so we fill the null values with the placeholder as not availabe here.
# Out:
# C:\Users\Ramandeep\AppData\Local\Temp\ipykernel_14204\2932572023.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['comments'].fillna('Not Available', inplace=True) # so we fill the null values with the placeholder as not availabe here.

# %%
df.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %%
# 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
df.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
df.describe(include = 'all')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
# mean            NaN    NaN                       NaN                  NaN
# std             NaN    NaN                       NaN                  NaN
# min             NaN    NaN                       NaN                  NaN
# 25%             NaN    NaN                       NaN                  NaN
# 50%             NaN    NaN                       NaN                  NaN
# 75%             NaN    NaN                       NaN                  NaN
# max             NaN    NaN                       NaN                  NaN
#
#                published_at    view_count         likes      dislikes  \
# ...

# %%
df.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
#  first we see our numerical column summary
# count :- our total number counts for view_count has 3.742200e+04 here 04 means 10**4 which very high and for likes 3.742200e+04, for our dislikes 3.742200e+04 and for comment_count our count has 3.742200e+04.
# mean :- into our view_count mean has a 1.668147e+05 which is our average value claculated by sum of obsevation//number of observations.
       #   & into our likes mean has a 5.697838e+06 which is our average value claculated by sum of obsevation//number of observations.
       #   & into our dislikes mean has a 4.989862e+03 which is our average value claculated by sum of obsevation//number of observations.
       #   & into our comment_count mean has a 9.924930e+03 which is our average value claculated by sum of obsevation//number of observations.
# std :- here into our view_counts standard devation is to be 2.426622e+07 its our a measure of the dispersion of values.
      #  into our likes standard devation is to be 5.375670e+05 its our a measure of the dispersion of values.
      #  into our dislikes standard devation is to be 3.070824e+04 its our a measure of the dispersion of values.
      #  into our comment_count standard devation is to be 1.171003e+05 its our a measure of the dispersion of values.
# min :- here into our view_count  we see our minimum value into the column is to be 2.036800e+04.
      #  & into our likes  we see our minimum value into the column is to be 0.000000e+00.
      #  & into our dilikes  we see our minimum value into the column is to be 0.000000e+00.
      #  & into our comment_count  we see our minimum value into the column is to be 0.000000e+00.
# max :- here into our view_count we can see our maximum value into the column is to be 1.322797e+09.   note:- this min and max value we can fetch after removing the outlires if any outliers is their into the data
      #  & into our likes we can see our maximum value into the column is to be 3.183768e+07.
      #  & into our dislikes we can see our maximum value into the column is to be 2.397733e+06.
      #  & into our comment_count we can see our maximum value into the column is to be 1.607103e+07.

# 25%, 50%, 75%: Quartiles, indicating the distribution of values.
# The 25th percentile (Q1) is the value below which 25% of the data falls. This means that 25% of the data points are less than or equal to this value, while the remaining 75% of the data points are greater than this value.
# The 50th percentile (Q2) is the value below which 50% of the data falls. This means that 50% of the data points are less than or equal to this value, while the remaining 50% of the data points are greater than this value.
# The 75th percentile (Q3) is the value below which 75% of the data falls. This means that 75% of the data points are less than or equal to this value, while the remaining 25% of the data points are greater than this value.


# now we see our numerical column summary:-
  # count the total number of rows(cells) for video_id,title,channel_id,channel_title,published_at is to 37422.
  # the top value for video_id --0bCF-iK2E and title www and for channel_id UCNAf1k0yIjyGu3k9BwAg3lg and for channel_title Sky Sports Football and for published at 2020-10-16 04:00:10.
  # Here in categorical column frequency refers to the number of time a particular category repeat itself into a dataset as we see from the data set
  # in our video_id	has a frequency of 1 title has a frequency of 21 channel_id has a frequency of 533 channel_title has a frequency of 533 published_at has a frequency of 6.

# %%
# 5. Convert datatype of column published_at from object to pandas datetime.

# %%
import datetime as dt

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  datetime64[ns]
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37422 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 3.4+ MB

# %%
# 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
 df['published_month'] = df['published_at'].dt.month

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
# 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
 df['published_month'] = df['published_at'].dt.month_name()

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
# 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
df[['title','published_month']].groupby('published_month').count().sort_values(by = 'title', ascending = False)
# Out:
#                  title
# published_month
# October           4991
# September         4880
# November          4851
# August            4262
# December          3072
# July              2340
# June              2316
# March             2258
# February          2137
# April             2126
# January           2108
# May               2081

# %%
# 9. Find the count of unique video_id, channel_id and channel_title.

# %%
len(df['video_id'].unique())
# Out:
# 37422

# %%
len(df['channel_id'].unique())
# Out:
# 10961

# %%
len(df['channel_title'].unique())
# Out:
# 10883

# %%
# 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos

# %%
df[['channel_title','published_month']].groupby('channel_title').count().sort_values(by = 'published_month' , ascending = False).head(10)
# Out:
#                      published_month
# channel_title
# Sky Sports Football              533
# The United Stand                 301
# BT Sport                         246
# NBA                              209
# NFL                              162
# WWE                              122
# SSSniperWolf                      99
# SSundee                           98
# FORMULA 1                         87
# NHL                               86

# %%
df[['channel_title','published_month']].groupby('channel_title').count().sort_values(by = 'published_month' , ascending = False).tail(10)
# Out:
#                 published_month
# channel_title
# Karchez                       1
# Karate Combat                 1
# Kaptain Kuba                  1
# Kanye West                    1
# Kannur kitchen                1
# Kannada Cinema                1
# KanalD                        1
# Kanak News                    1
# Kamille Ramos                 1
# zoom                          1

# %%
# 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences

# %%
df[['title','likes']].groupby('title').sum().sort_values(by = 'likes' , ascending = False)
# Out:
#                                                        likes
# title
# BTS () 'Dynamite' Official MV                       31837675
# BTS () 'Butter' Official MV                         20649409
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V     17864527
# BTS () 'Life Goes On' Official MV                   16354127
# BTS () 'Permission to Dance' Official MV            15449003
# ...                                                      ...
# Virtual Pub Quiz, Live! Saturday 12th December            97
# Small Business Loans from OnDeck                          29
# Tims For Good: A Taste Of The Familiar                    28
# Leading the Charge | Circle K                             22
# Kim Kardashian's Must-See Moments on "Saturday ...         0
#
# [37113 rows x 1 columns]

# %%
# 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
df[['title','dislikes']].groupby('title').sum().sort_values(by = 'dislikes' , ascending = False)
# Out:
#                                                     dislikes
# title
# Cuties | Official Trailer | Netflix                  2397733
# BTS () 'Dynamite' Official MV                        1814333
# Cardi B - WAP feat. Megan Thee Stallion [Offici...   1331181
# 52 GAJ KA DAMAN | PRANJAL DAHIYA | AMAN JAJI | ...   1259533
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V      1253187
# ...                                                      ...
# YONEX Thailand Open | Day 3: Saina Nehwal (IND)...         7
# Leeds Rhinos vs Wakefield Trinity | Super Leagu...         6
# Live Stream: Hampshire v Yorkshire - LV= County...         4
# Tims For Good: A Taste Of The Familiar                     3
# Kim Kardashian's Must-See Moments on "Saturday ...         0
#
# [37113 rows x 1 columns]

# %%
# The video "Cuties | Official Trailer | Netflix" has garnered the highest number of dislikes, indicating it may have sparked significant controversy or disagreement among viewers.
# On the other hand, "Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News" has the fewest dislikes, suggesting it's likely a popular and well-received video.

# NOTE: this infrence made upon the base of that while all other elements of the data will remains constant.

# %%
# 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
correlation = df['view_count'].corr(df['dislikes'])

# %%
correlation
# Out:
# 0.6844687753905547

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.scatterplot(y = 'dislikes',x = 'view_count',data = df)
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %%
# 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January

# %%
d = df[df['published_month']=='January']

# %%
d
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
count_of_videos = len(d)

# %%
count_of_videos
# Out:
# 2108
